# %%
from bs4 import BeautifulSoup as BS
import pandas as pd
import requests
import webbrowser
import urllib.request

# %%
url='https://www.tripadvisor.in/Hotel_Review-g297698-d3633245-Reviews-or20-Mulia_Resort-Nusa_Dua_Benoa_South_Kuta_Bali.html'
req = urllib.request.Request(url)
req.add_header('User-Agent', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:106.0) Gecko/20100101 Firefox/106.0')
req.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8')
req.add_header('Accept-Language', 'en-US,en;q=0.5')
response = urllib.request.urlopen(req)
html_code = response.read().decode('utf-8')
soup=BS(html_code,'html.parser')
totalReviews=soup.find('span',class_='biGQs _P pZUbB KxBGd').text[:-8].replace(',','')
hotelName=soup.find('h1',id='HEADING').text
reviewHeads=[i.text for i in soup.find_all('span',class_='JbGkU Cj')]
reviewContent=[i.text for i in soup.find_all('span',class_='orRIx Ci _a C')]
reviewerNdate = [i.text for i in soup.find_all('div', class_='tVWyV _Z o S4 H3 Ci') if 'wrote a review' in i.text]
reviewerandDate=[]
for i in reviewerNdate:
    reviewerandDate.append(i.split('wrote a review '))
finalDate=[]
finalreviewer=[]
for i in reviewerandDate:
    finalDate.append(i[1])
    finalreviewer.append(i[0])
ratings=[i.find('title').text[0:3] for i in soup.find_all('div',class_='kmMXA _T Gi')]
tempHotelLocation= [i.text for i in soup.find_all('span',class_='biGQs _P pZUbB KxBGd')]
hotelLocation=tempHotelLocation[1]
df = pd.DataFrame({
    'Hotel Name': hotelName,
    'Hotel Location': hotelLocation,
    'Reviewer': finalreviewer,
    'Rating':ratings,
    'Date of Review': finalDate,
    'Review':reviewHeads,
    'Complete Review':reviewContent
})
return df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [218], line 35
#      25 hotelLocation=tempHotelLocation[1]
#      26 newdf = pd.DataFrame({
#      27     'Hotel Name': hotelName,
#      28     'Hotel Location': hotelLocation,
#    (...)
#      33     'Complete Review':reviewContent
#      34 })
# ---> 35 if newdf!=df:
#      36     df = pd.concat([df, newdf], ignore_index=True)
#      37 df
#
# File c:\users\viren\appdata\local\programs\python\python38\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File c:\users\viren\appdata\local\programs\python\python38\lib\site-packages\pandas\core\arraylike.py:46, in OpsMixin.__ne__(self, other)
#      44 @unpack_zerodim_and_defer("__ne__")
#      45 def __ne__(self, other):
# ---> 46     return self._cmp_method(other, operator.ne)
#
# File c:\users\viren\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:7579, in DataFrame._cmp_method(self, other, op)
#    7576 def _cmp_method(self, other, op):
#    7577     axis = 1  # only relevant for Series other case
# -> 7579     self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    7581     # See GH#4537 for discussion of scalar op behavior
#    7582     new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File c:\users\viren\appdata\local\programs\python\python38\lib\site-packages\pandas\core\ops\__init__.py:289, in align_method_FRAME(left, right, axis, flex, level)
#     287             left, right = left.align(right, join="outer", level=level, copy=False)
#     288         else:
# --> 289             raise ValueError(
#     290                 "Can only compare identically-labeled DataFrame objects"
#     291             )
#     292 elif isinstance(right, ABCSeries):
#     293     # axis=1 is default for DataFrame-with-Series op
#     294     axis = left._get_axis_number(axis) if axis is not None else 1
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %%
def getReviews(url):
    req = urllib.request.Request(url)
    req.add_header('User-Agent', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:106.0) Gecko/20100101 Firefox/106.0')
    req.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8')
    req.add_header('Accept-Language', 'en-US,en;q=0.5')
    response = urllib.request.urlopen(req)
    html_code = response.read().decode('utf-8')
    soup=BS(html_code,'html.parser')
    totalReviews=soup.find('span',class_='biGQs _P pZUbB KxBGd').text[:-8].replace(',','')
    hotelName=soup.find('h1',id='HEADING').text
    reviewHeads=[i.text for i in soup.find_all('span',class_='JbGkU Cj')]
    reviewContent=[i.text for i in soup.find_all('span',class_='orRIx Ci _a C')]
    reviewerNdate = [i.text for i in soup.find_all('div', class_='tVWyV _Z o S4 H3 Ci') if 'wrote a review' in i.text]
    reviewerandDate=[]
    for i in reviewerNdate:
        reviewerandDate.append(i.split('wrote a review '))
    finalDate=[]
    finalreviewer=[]
    for i in reviewerandDate:
        finalDate.append(i[1])
        finalreviewer.append(i[0])
    ratings=[i.find('title').text[0:3] for i in soup.find_all('div',class_='kmMXA _T Gi')]
    tempHotelLocation= [i.text for i in soup.find_all('span',class_='biGQs _P pZUbB KxBGd')]
    hotelLocation=tempHotelLocation[1]
    df = pd.DataFrame({
        'Hotel Name': hotelName,
        'Hotel Location': hotelLocation,
        'Reviewer': finalreviewer,
        'Rating':ratings,
        'Date of Review': finalDate,
        'Review':reviewHeads,
        'Complete Review':reviewContent
    })
    return [df,totalReviews]

# %%
url='https://www.tripadvisor.in/Hotel_Review-g297698-d3633245-Reviews-Mulia_Resort-Nusa_Dua_Benoa_South_Kuta_Bali.html'
split_url = url.split("Reviews-")
first_part = split_url[0] + "Reviews-or"
second_part = "-" + split_url[1]
result = getReviews(url)
df=result[0]
totalReviews=result[1]
df
urls = [f"{first_part}{i}{second_part}" for i in range(10, int(totalReviews), 10)]
for i in urls:
    newdf=getReviews(i)
    df = pd.concat([df, newdf], ignore_index=True)
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       3 first_part = split_url[0] + "Reviews-or"
#       4 second_part = "-" + split_url[1]
# ----> 5 result = getReviews(url)
#       6 df=result[0]
#       7 totalReviews=result[1]
#
# Cell In[3], line 6, in getReviews(url)
#       4 req.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8')
#       5 req.add_header('Accept-Language', 'en-US,en;q=0.5')
# ----> 6 response = urllib.request.urlopen(req)
#       7 html_code = response.read().decode('utf-8')
#       8 soup=BS(html_code,'html.parser')
#
# File ~\anaconda3\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\anaconda3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\anaconda3\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\anaconda3\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File ~\anaconda3\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\anaconda3\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
df.to_excel('trial1.xlsx', index=False, engine='openpyxl')

# %%
url='https://www.tripadvisor.in/Hotel_Review-g297698-d3633245-Reviews-Mulia_Resort-Nusa_Dua_Benoa_South_Kuta_Bali.html'
df=getReviews(url)
df
# Out:
#      Hotel Name                                     Hotel Location  \
# 0  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 1  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 2  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 3  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 4  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 5  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 6  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 7  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 8  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 9  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
#
#              Reviewer Rating Date of Review  \
# 0     aandsaustralia     5.0       Nov 2023
# 1       Ozmandapanda     5.0       Jan 2020
# 2  FrequentTraveler9     5.0       Mar 2022
# 3      Sinta Jakarta     5.0       Mar 2022
# 4           Hian Ong     4.0       Feb 2020
# 5                HJP     4.0       Jan 2020
# 6        erictan1986     5.0       Jan 2022
# 7            Danti P     3.0       Oct 2022
# 8         Ifan Henry     5.0       Mar 2022
# 9             Kurt L     4.0       Mar 2020
#
#                                     Review  \
# 0                     One word: incredible
# 1            You won't want to leave......
# 2         Calming place, good for vacation
# 3               Amazing time @Mulia Resort
# 4             Like Gulliver in Brobdingnag
# 5                      The perfect package
# 6           Still one the best in Nusa Dua
# 7                      A good 5 star hotel
# 8  My first option on my next trip to Bali
# 9                    Don't drink the water
#
#                                      Complete Review
# 0  We were recommended this resort by my wife's f...
# 1  We took our three young kids to this resort, a...
# 2  The room we got was at a quiet location with o...
# 3  We had the short break during covid time, so w...
# 4  If this review was just about the restaurants,...
# 5  My partner and I decided to spend a little ext...
# 6  We returned to stay in Mulia Resort after 2 ye...
# 7  A good 5 star hotel with below average service...
# 8  This resort is so huge. The staffs are very fr...
# 9  Mulla is an amazing spectacle- huge statues in...
